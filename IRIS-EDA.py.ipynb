# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("E:\Work\Data Science\Projects\Iris Data Analysis\iris.csv", header=None )
#if we do not provide the header statement then the first row is considered as column names

# %%
print(df1.head())
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df1.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df1.tail()
# Out:
#        0    1    2    3               4
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df1.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
first = df1.head(7)
print(first)
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa
# 6  4.6  3.4  1.4  0.3  Iris-setosa

# %%
from random import sample
#create a random index
randomIndex = np.array(sample(range(len(df1)), 5))
#Get 5 random rows
df1Sample = df1.ix[randomIndex]
print(df1Sample)
# Out:
#        0    1    2    3                4
# 89   5.5  2.5  4.0  1.3  Iris-versicolor
# 73   6.1  2.8  4.7  1.2  Iris-versicolor
# 20   5.4  3.4  1.7  0.2      Iris-setosa
# 138  6.0  3.0  4.8  1.8   Iris-virginica
# 83   6.0  2.7  5.1  1.6  Iris-versicolor

# %%
#now to check if our data frame contains any missing values
pd.isnull(df1)
# Out:
#          0      1      2      3      4
# 0    False  False  False  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4    False  False  False  False  False
# 5    False  False  False  False  False
# 6    False  False  False  False  False
# 7    False  False  False  False  False
# 8    False  False  False  False  False
# 9    False  False  False  False  False
# 10   False  False  False  False  False
# 11   False  False  False  False  False
# 12   False  False  False  False  False
# 13   False  False  False  False  False
# 14   False  False  False  False  False
# 15   False  False  False  False  False
# 16   False  False  False  False  False
# 17   False  False  False  False  False
# 18   False  False  False  False  False
# 19   False  False  False  False  False
# 20   False  False  False  False  False
# 21   False  False  False  False  False
# 22   False  False  False  False  False
# ...

# %%
# Import `RandomForestClassifier`
from sklearn.ensemble import RandomForestClassifier

# Isolate Data, class labels and column values
X = df1.iloc[:,0:4]
Y = df1.iloc[:,-1]
names = df1.columns.values

# Build the model
rfc = RandomForestClassifier()

# Fit the model
rfc.fit(X, Y)

# Print the results
print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), rfc.feature_importances_), names), reverse=True))
# Out:
# Features sorted by their score:
# [(0.51800000000000002, 2), (0.35499999999999998, 3), (0.10050000000000001, 0), (0.026599999999999999, 1)]

# %%
#NOW VISUALISING THE FEATURE IMPORTANCE 
#Import `pyplot` and `numpy`
import matplotlib.pyplot as plt
import numpy as np

# Isolate feature importances 
importance = rfc.feature_importances_

# Sort the feature importances 
sorted_importances = np.argsort(importance)

# Insert padding
padding = np.arange(len(names)-1) + 0.5

# Plot the data
plt.barh(padding, importance[sorted_importances], align='center')

# Customize the plot
plt.yticks(padding, names[sorted_importances])
plt.xlabel("Relative Importance")
plt.title("Variable Importance")

# Show the plot
plt.show()

# %%
#reading data again into df1 with column heading this time
df1 = pd.read_csv("E:\Work\Data Science\Projects\Iris Data Analysis\iris.csv")

# %%
df1.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
del df1['Class']

# %%
df1.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
#Now we need to plot the feature importance but for that we need to reduce dimensions of our features to 2
#the step for dimensionality reduction using PCA are given here
# Import `PCA` from `sklearn.decomposition`
from sklearn.decomposition import PCA

# Build the model
pca = PCA(n_components=2)

# Reduce the data, output is ndarray
reduced_data = pca.fit_transform(df1)

# Inspect shape of the `reduced_data`
reduced_data.shape

# print out the reduced data
print(reduced_data)
# Out:
# [[-2.68420713  0.32660731]
#  [-2.71539062 -0.16955685]
#  [-2.88981954 -0.13734561]
#  [-2.7464372  -0.31112432]
#  [-2.72859298  0.33392456]
#  [-2.27989736  0.74778271]
#  [-2.82089068 -0.08210451]
#  [-2.62648199  0.17040535]
#  [-2.88795857 -0.57079803]
#  [-2.67384469 -0.1066917 ]
#  [-2.50652679  0.65193501]
#  [-2.61314272  0.02152063]
#  [-2.78743398 -0.22774019]
#  [-3.22520045 -0.50327991]
#  [-2.64354322  1.1861949 ]
#  [-2.38386932  1.34475434]
#  [-2.6225262   0.81808967]
#  [-2.64832273  0.31913667]
#  [-2.19907796  0.87924409]
#  [-2.58734619  0.52047364]
#  [-2.3105317   0.39786782]
#  [-2.54323491  0.44003175]
#  [-3.21585769  0.14161557]
#  [-2.30312854  0.10552268]
#  [-2.35617109 -0.03120959]
#  [-2.50791723 -0.13905634]
#  [-2.469056    0.13788731]
#  [-2.56239095  0.37468456]
#  [-2.63982127  0.31929007]
#  [-2.63284791 -0.19007583]
#  [-2.58846205 -0.19739308]
#  [-2.41007734  0.41808001]
#  [-2.64763667  0.81998263]
#  [-2.59715948  1.10002193]
# ...

# %%
#now that we have reduced dimensions if our data we can now plot it
import matplotlib.pyplot as plt

plt.scatter(reduced_data[:,0], reduced_data[:,1], cmap = 'viridis')

plt.show()

# %%
df1 = pd.read_csv("E:\Work\Data Science\Projects\Iris Data Analysis\iris.csv")

# %%
#correlation identification with bokeh
# Import the necessary modules
from bokeh.charts import Scatter, output_file, show

# Construct the scatter plot
p = Scatter(df1, x='Petal_length', y='Petal_width', color="Class", title="Petal Length vs Petal Width",
            xlabel="Sepal Length", ylabel="Sepal Width")

# Output the file 
output_file('scatter.html')

# Show the scatter plot
show(p)
# Out:
# INFO:bokeh.core.state:Session output file 'scatter.html' already exists, will be overwritten.

# %%
#correlation identification with pandas
# Pearson correlation
df1.corr()
# Out:
#               Sepal_length  Sepal_width  Petal_length  Petal_width
# Sepal_length      1.000000    -0.109369      0.871754     0.817954
# Sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# Petal_length      0.871754    -0.420516      1.000000     0.962757
# Petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
# Kendall Tau correlation
df1.corr('kendall')
# Out:
#               Sepal_length  Sepal_width  Petal_length  Petal_width
# Sepal_length      1.000000    -0.072112      0.717624     0.654960
# Sepal_width      -0.072112     1.000000     -0.182391    -0.146988
# Petal_length      0.717624    -0.182391      1.000000     0.803014
# Petal_width       0.654960    -0.146988      0.803014     1.000000

# %%
# Spearman Rank correlation
df1.corr('spearman')
# Out:
#               Sepal_length  Sepal_width  Petal_length  Petal_width
# Sepal_length      1.000000    -0.159457      0.881386     0.834421
# Sepal_width      -0.159457     1.000000     -0.303421    -0.277511
# Petal_length      0.881386    -0.303421      1.000000     0.936003
# Petal_width       0.834421    -0.277511      0.936003     1.000000
